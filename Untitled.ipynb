# %% [markdown]
# # Checking to see if younger soccer players are more expensive to buy.
# This is checking to see what the age trends are through football and wether age has any correlation with price in the transfer market.
#
# First, the imports:

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# During startup - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.1     ✔ purrr   1.0.1
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df = pd.read_csv('data/leagues.csv')
len(df)
# Out:
# 41051

# %%
#remove rows with the player_name Daniel Wilkinson and Fred Keenor

df = df[df.player_name != 'Daniel Wilkinson']
df = df[df.player_name != 'Fred Keenor']
df = df[df.player_name != 'Daniel Ravier']
df = df[df.player_name != 'Marcel Geißlerr']
df = df[df.player_name != 'Hervé Guy']
df = df[df.player_name != 'Bo Lasse Henrichs']
df = df[df.player_name != 'Tommaso Pieroni']
df = df[df.player_name != 'Jamairo Appiah']
df = df[df.player_name != 'Hamza Samari']
df = df[df.player_name != 'Luis Quintero']

# %%
# %%R -i df -w 800 -h 600
#
# ggplot(df, aes(x=fee_cleaned, y=age)) +
#     geom_point()

# %%
# %%R
#
# ggplot(df, aes(x=fee_cleaned, y=age)) +
#     geom_point() +
#     geom_smooth(method='lm', formula= y~x)

# %%
# %%R
#
# model <- lm(age ~ fee_cleaned, data=df)
#
# summary(model)
# Out:
# Call:
# lm(formula = age ~ fee_cleaned, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.6987 -3.2532 -0.6088  2.7355 17.2903
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 25.709668   0.035092  732.63   <2e-16 ***
# fee_cleaned -0.054962   0.003302  -16.64   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.169 on 16166 degrees of freedom
#   (24883 observations deleted due to missingness)
# Multiple R-squared:  0.01685,	Adjusted R-squared:  0.01678
# F-statistic:   277 on 1 and 16166 DF,  p-value: < 2.2e-16
