# %% [markdown]
# # Checking to see if younger soccer players are more expensive to buy.
# This is checking to see what the age trends are through football and wether age has any correlation with price in the transfer market.
#
# First, the imports:

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# During startup - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.1     ✔ purrr   1.0.1
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df = pd.read_csv('data/leagues.csv')
df.head()
# Out:
#    Unnamed: 0         club_name       player_name   age     position  \
# 0           0  Middlesbrough FC      Tommy Wright  26.0  Left Winger
# 1           1  Middlesbrough FC  Jonathan Gittens  28.0      defence
# 2           2  Middlesbrough FC      Chris Morris  28.0   Right-Back
# 3           3  Middlesbrough FC       Ben Roberts  17.0   Goalkeeper
# 4           4  Middlesbrough FC         Andy Todd  17.0  Centre-Back
#
#   club_involved_name      fee transfer_movement transfer_period  fee_cleaned  \
# 0          Leicester  €910Th.                in          Summer         0.91
# 1        Southampton  €250Th.                in          Summer         0.25
# 2             Celtic        ?                in          Summer          NaN
# 3           Boro U18        -                in          Summer          NaN
# 4           Boro U18        -                in          Summer          NaN
#
#       league_name  year     season
# 0  Premier League  1992  1992/1993
# ...

# %%
#show me players with highest age

df.sort_values(by='age', ascending=True).head(10)
# Out:
#         Unnamed: 0             club_name        player_name   age  \
# 23791        23791  VfB Leipzig (- 2004)     Marcel Geißler   9.0
# 83369        83369             SC Bastia          Hervé Guy  11.0
# 31817        31817    Fortuna Düsseldorf  Bo Lasse Henrichs  11.0
# 99118        99118             Empoli FC    Tommaso Pieroni  11.0
# 157082      157082            PEC Zwolle     Jamairo Appiah  12.0
# 146956      146956       Fortuna Sittard       Hamza Samari  12.0
# 74546        74546         Villarreal CF      Luis Quintero  12.0
# 79693        79693   Paris Saint-Germain    Christophe Olol  13.0
# 120839      120839               AS Roma    Raffaele Romano  14.0
# 80020        80020   Paris Saint-Germain    Christophe Olol  14.0
#
#                   position club_involved_name                      fee  \
# 23791             midfield            Unknown            free transfer
# 83369   Defensive Midfield      SC Bastia U19                        -
# ...

# %%
#Fuck it, let's filter for year more than 2016

df = df[df['year'] > 2016]

# %% [markdown]
# ## Hypothesis: Clubs pay more money for younger players.
#
# ### Null Hypothesis: There is no relationship between age and fees paid for a player by the top 5 leagues in Europe

# %%
#remove rows with the player_name Daniel Wilkinson and Fred Keenor

df = df[df.player_name != 'Daniel Wilkinson']
df = df[df.player_name != 'Fred Keenor']
df = df[df.player_name != 'Daniel Ravier']
df = df[df.player_name != 'Marcel Geißlerr']
df = df[df.player_name != 'Hervé Guy']
df = df[df.player_name != 'Bo Lasse Henrichs']
df = df[df.player_name != 'Tommaso Pieroni']
df = df[df.player_name != 'Jamairo Appiah']
df = df[df.player_name != 'Hamza Samari']
df = df[df.player_name != 'Luis Quintero']

# %%
# %%R -i df -w 800 -h 600
#
# ggplot(df, aes(x=age, y=fee_cleaned)) +
#     geom_point()
